# %%
#!pip install torchvision

# %%
import torch
import torch.nn
import torchvision.transforms as transforms
import torchvision.datasets
from torch.autograd import Variable
from torch.nn import Parameter
import torch.nn as nn
from torch import Tensor
import torch.nn.functional as F
from torch.utils.data import DataLoader
import math

import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %%
class LSTM(nn.Module):
    def __init__(self, num_classes, input_size, hidden_size, num_layers, seq_length):
        super(LSTM, self).__init__()
        self.num_classes = num_classes # 클래스
        self.num_layers = num_layers # LSTM 계층 개수
        self.input_size = input_size  # 입력 크기(컬럼 개수)
        self.hidden_size = hidden_size # 은닉층의 뉴런 개수
        self.seq_length = seq_length # 시퀀스 길이

        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                          num_layers=num_layers, batch_first=True) # lstm 계층
        self.fc_1 =  nn.Linear(hidden_size, 128) # 완전연결층
        self.fc = nn.Linear(128, num_classes) # 출력층

        self.relu = nn.ReLU()
    
    def forward(self,x):
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) # 은닉상태 초기화
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) # 셀 상태 초기화
        
        output, (hn, cn) = self.lstm(x, (h_0, c_0)) # lstm 계층에 은닉 상태와 셀 상태 적용
        hn = hn.view(-1, self.hidden_size) # 완전연결층 적용을 위해 데이터 형태를 1차원으로 조정
        out = self.relu(hn)
        out = self.fc_1(out) 
        out = self.relu(out) 
        out = self.fc(out)
        return out

# %%
class GRU(nn.Module) :
    def __init__(self, num_classes, input_size, hidden_size, num_layers, seq_length) :
        super(GRU, self).__init__()
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.gru = nn.GRU(input_size=input_size,hidden_size=hidden_size,
                         num_layers=num_layers,batch_first=True)
        self.fc_1 = nn.Linear(hidden_size, 128)
        self.fc = nn.Linear(128, num_classes)
        self.relu = nn.ReLU()
        
    def forward(self, x) :
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))
        output, (hn) = self.gru(x, (h_0))
        hn = hn.view(-1, self.hidden_size)
        out = self.relu(hn)
        out = self.fc_1(out)
        out = self.relu(out)
        out = self.fc(out)
        return out

# %%
plt.style.use('seaborn-whitegrid')

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

cuda = True if torch.cuda.is_available() else False
Tensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor

torch.manual_seed(125)

if torch.cuda.is_available() :
    torch.cuda.manual_seed_all(125)
# Out:
# C:\Users\wandong\AppData\Local\Temp\ipykernel_1252\1616429856.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
#!pip install yfinance

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:/Users/wandong/Desktop/미래에셋/본선\data/FINALDATA/sm.csv")
df.set_index('DATE',inplace=True)
df
# Out:
#                 Open      High       Low     Close    Volume    Change  \
# DATE
# 2023-01-02   77300.0   78000.0   73300.0   75200.0  425582.0 -0.019557
# 2023-01-03   74900.0   78400.0   74700.0   77200.0  462240.0  0.026596
# 2023-01-04   77200.0   77400.0   74200.0   75200.0  337977.0 -0.025907
# 2023-01-05   75600.0   76900.0   73600.0   74400.0  297806.0 -0.010638
# 2023-01-06   74000.0   74400.0   71700.0   73900.0  441861.0 -0.006720
# ...              ...       ...       ...       ...       ...       ...
# 2023-06-26  110300.0  112000.0  109400.0  109700.0  193953.0 -0.011712
# 2023-06-27  108600.0  110900.0  106400.0  109700.0  238510.0  0.000000
# 2023-06-28  109100.0  110200.0  107300.0  107300.0  213378.0 -0.021878
# 2023-06-29  107400.0  110500.0  105300.0  107000.0  258872.0 -0.002796
# 2023-06-30  107000.0  108800.0  105200.0  106800.0  202510.0 -0.001869
#
#                    MACD       Signal           PSAR          upper  ...  \
# DATE                                                                ...
# 2023-01-02  1117.160676  2197.145019   81365.440000   81520.872356  ...
# 2023-01-03   998.004622  1957.316939   80881.513600   81056.242836  ...
# 2023-01-04   733.731308  1712.599813   80426.622784   81143.370206  ...
# 2023-01-05   454.500292  1460.979909   79999.025417   81266.921675  ...
# 2023-01-06   190.664023  1206.916732   79597.083892   81481.985647  ...
# ...                 ...          ...            ...            ...  ...
# 2023-06-26  2278.430780  2139.225965  107945.212075  122635.488145  ...
# 2023-06-27  1879.125841  2087.205941  124300.000000  122697.786521  ...
# 2023-06-28  1353.412560  1940.447265  123942.000000  122638.034600  ...
# 2023-06-29   902.173807  1732.792573  123591.160000  122555.996116  ...
# 2023-06-30   522.403572  1490.714773  122859.513600  122385.377578  ...
#
#                    OBV           FI   keyword  view_log_like_sum  \
# DATE
# 2023-01-02   5768696.0 -638373000.0  24.96469       7.399767e+07
# 2023-01-03   6230936.0  924480000.0  14.15332       1.464846e+05
# 2023-01-04   5892959.0 -675954000.0  14.04271       1.397045e+06
# 2023-01-05   5595153.0 -238244800.0  13.70464       1.008613e+07
# 2023-01-06   5153292.0 -220930500.0  14.24473       4.916204e+06
# ...                ...          ...       ...                ...
# 2023-06-26  35864179.0 -252138900.0  16.79784       1.123055e+08
# 2023-06-27  35864179.0          0.0  14.64082       2.600580e+07
# 2023-06-28  35650801.0 -512107200.0  15.29111       2.217829e+07
# 2023-06-29  35391929.0  -77661600.0  15.00185       1.413458e+06
# 2023-06-30  35189419.0  -40502000.0  16.08035       1.867942e+08
#
#             view_log_like_avg      count      trend  DAY   SENTIMENT  \
# DATE
# 2023-01-02       1.479953e+07   2.500000  11.923327    월   42.254562
# 2023-01-03       1.464846e+05   1.000000  14.817139    화  239.101168
# 2023-01-04       1.397045e+06   1.000000  17.064487    수  -60.814626
# 2023-01-05       3.362043e+06   3.000000  18.201785    목  194.386103
# 2023-01-06       2.458102e+06   2.000000  17.810474    금  275.580510
# ...                       ...        ...        ...  ...         ...
# 2023-06-26       5.552657e+07   2.666667  18.846669    월   60.967249
# 2023-06-27       8.668600e+06   3.000000  19.215023    화         NaN
# 2023-06-28       3.696381e+06   6.000000  18.622752    수         NaN
# 2023-06-29       7.067291e+05   2.000000  16.615763    목         NaN
# 2023-06-30       1.698129e+07  11.000000  20.387910    금         NaN
#
#                 EVENT
# DATE
# 2023-01-02  20.021539
# 2023-01-03        NaN
# 2023-01-04        NaN
# 2023-01-05        NaN
# 2023-01-06   0.045972
# ...               ...
# 2023-06-26        NaN
# 2023-06-27        NaN
# 2023-06-28        NaN
# 2023-06-29        NaN
# 2023-06-30        NaN
#
# [125 rows x 25 columns]

# %%
df.isna().sum()
# Out:
# Open                  2
# High                  2
# Low                   2
# Close                 2
# Volume                2
# Change                2
# MACD                  2
# Signal                2
# PSAR                  2
# upper                 2
# middle                2
# lower                 2
# SlowK                 2
# SlowD                 2
# ROC                   2
# OBV                   2
# FI                    2
# keyword               2
# view_log_like_sum     2
# view_log_like_avg     2
# count                 2
# trend                 2
# DAY                   2
# SENTIMENT             7
# EVENT                87
# dtype: int64

# %%
df.loc[df['Close'].isna()]
# Out:
#             Open  High  Low  Close  Volume  Change  MACD  Signal  PSAR  upper  \
# DATE
# 2023-03-01   NaN   NaN  NaN    NaN     NaN     NaN   NaN     NaN   NaN    NaN
# 2023-05-05   NaN   NaN  NaN    NaN     NaN     NaN   NaN     NaN   NaN    NaN
#
#             ...  OBV  FI  keyword  view_log_like_sum  view_log_like_avg  \
# DATE        ...
# 2023-03-01  ...  NaN NaN      NaN                NaN                NaN
# 2023-05-05  ...  NaN NaN      NaN                NaN                NaN
#
#             count  trend  DAY  SENTIMENT      EVENT
# DATE
# 2023-03-01    NaN    NaN  NaN        NaN -24.976292
# 2023-05-05    NaN    NaN  NaN        NaN  99.955629
#
# [2 rows x 25 columns]

# %%
df.drop(index='2023-05-05',inplace=True)

# %%
df.fillna(0,inplace=True)
df.isna().sum()
# Out:
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume               0
# Change               0
# MACD                 0
# Signal               0
# PSAR                 0
# upper                0
# middle               0
# lower                0
# SlowK                0
# SlowD                0
# ROC                  0
# OBV                  0
# FI                   0
# keyword              0
# view_log_like_sum    0
# view_log_like_avg    0
# count                0
# trend                0
# DAY                  0
# SENTIMENT            0
# EVENT                0
# dtype: int64

# %%
df.info()
drop_columns=['Close','view_log_like_sum','view_log_like_avg','count','DAY']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124 entries, 2023-01-02 to 2023-06-30
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Open               124 non-null    float64
#  1   High               124 non-null    float64
#  2   Low                124 non-null    float64
#  3   Close              124 non-null    float64
#  4   Volume             124 non-null    float64
#  5   Change             124 non-null    float64
#  6   MACD               124 non-null    float64
#  7   Signal             124 non-null    float64
#  8   PSAR               124 non-null    float64
#  9   upper              124 non-null    float64
#  10  middle             124 non-null    float64
#  11  lower              124 non-null    float64
#  12  SlowK              124 non-null    float64
#  13  SlowD              124 non-null    float64
#  14  ROC                124 non-null    float64
#  15  OBV                124 non-null    float64
#  16  FI                 124 non-null    float64
#  17  keyword            124 non-null    float64
#  18  view_log_like_sum  124 non-null    float64
#  19  view_log_like_avg  124 non-null    float64
#  20  count              124 non-null    float64
#  21  trend              124 non-null    float64
#  22  DAY                124 non-null    object
#  23  SENTIMENT          124 non-null    float64
#  24  EVENT              124 non-null    float64
# dtypes: float64(24), object(1)
# memory usage: 25.2+ KB

# %%
fig = df['Close'].plot()

# %%
X = df.drop(drop_columns, axis=1) # X, y 분리
y = df[['Close']]

# %%
X.fillna(0,inplace=True)
X.isna().sum()
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124 entries, 2023-01-02 to 2023-06-30
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       124 non-null    float64
#  1   High       124 non-null    float64
#  2   Low        124 non-null    float64
#  3   Volume     124 non-null    float64
#  4   Change     124 non-null    float64
#  5   MACD       124 non-null    float64
#  6   Signal     124 non-null    float64
#  7   PSAR       124 non-null    float64
#  8   upper      124 non-null    float64
#  9   middle     124 non-null    float64
#  10  lower      124 non-null    float64
#  11  SlowK      124 non-null    float64
#  12  SlowD      124 non-null    float64
#  13  ROC        124 non-null    float64
#  14  OBV        124 non-null    float64
#  15  FI         124 non-null    float64
#  16  keyword    124 non-null    float64
#  17  trend      124 non-null    float64
#  18  SENTIMENT  124 non-null    float64
#  19  EVENT      124 non-null    float64
# dtypes: float64(20)
# memory usage: 20.3+ KB

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

ms = MinMaxScaler() # 0 ~ 1
ss = StandardScaler() # 평균 0, 분산 1

X_ss = ss.fit_transform(X)
y_ms = ms.fit_transform(y)

X_train = X_ss[:99, :] # 이부분 확인해보기!!!!!!!!!!!!!!!!!!!!
X_test = X_ss[99:, :]

y_train = y_ms[:99, :]
y_test = y_ms[99:, :]

print('Training Shape :', X_train.shape, y_train.shape)
print('Testing Shape :', X_test.shape, y_test.shape)
# Out:
# Training Shape : (99, 20) (99, 1)
# Testing Shape : (25, 20) (25, 1)

# %%
# 데이터셋 형태 및 크기 조정
X_train_tensors = Variable(torch.Tensor(X_train))
X_test_tensors = Variable(torch.Tensor(X_test))

y_train_tensors = Variable(torch.Tensor(y_train))
y_test_tensors = Variable(torch.Tensor(y_test))

X_train_tensors_f = torch.reshape(X_train_tensors, 
                                  (X_train_tensors.shape[0], 1, X_train_tensors.shape[1]))

X_test_tensors_f = torch.reshape(X_test_tensors,
                                (X_test_tensors.shape[0], 1, X_test_tensors.shape[1]))

print('Training Shape :', X_train.shape, y_train.shape)
print('Testing Shape :', X_test.shape, y_test.shape)
# Out:
# Training Shape : (99, 20) (99, 1)
# Testing Shape : (25, 20) (25, 1)

# %% [markdown]
# ## LSTM

# %%
class LSTM(nn.Module):
    def __init__(self, num_classes, input_size, hidden_size, num_layers, seq_length):
        super(LSTM, self).__init__()
        self.num_classes = num_classes # 클래스
        self.num_layers = num_layers # LSTM 계층 개수
        self.input_size = input_size  # 입력 크기(컬럼 개수)
        self.hidden_size = hidden_size # 은닉층의 뉴런 개수
        self.seq_length = seq_length # 시퀀스 길이

        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                          num_layers=num_layers, batch_first=True) # lstm 계층
        self.fc_1 =  nn.Linear(hidden_size, 128) # 완전연결층
        self.fc = nn.Linear(128, num_classes) # 출력층

        self.relu = nn.ReLU()
    
    def forward(self,x):
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) # 은닉상태 초기화
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) # 셀 상태 초기화
        
        output, (hn, cn) = self.lstm(x, (h_0, c_0)) # lstm 계층에 은닉 상태와 셀 상태 적용
        hn = hn.view(-1, self.hidden_size) # 완전연결층 적용을 위해 데이터 형태를 1차원으로 조정
        out = self.relu(hn)
        out = self.fc_1(out) 
        out = self.relu(out) 
        out = self.fc(out)
        return out

# %%
num_epochs = 5000
learning_rate = 0.001

input_size=20 # 칼럼 개수
hidden_size=20 # 은닉층 유닛 개수
num_layers=1 # LSTM 계층 개수

num_classes=1 # 클래스 개수
model = LSTM(num_classes, input_size, hidden_size, num_layers, X_train_tensors_f.shape[1])

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs) :
    outputs = model.forward(X_train_tensors_f) # 전방향 학습
    optimizer.zero_grad()
    loss = criterion(outputs, y_train_tensors) # 오차 계싼
    loss.backward() # 기울기 계산
    
    optimizer.step() # 오차 업데이트
    if epoch % 100 == 0 :
        print(f'Epoch : {epoch}, loss : {loss.item():1.5f}')
# Out:
# Epoch : 0, loss : 0.48997
# Epoch : 100, loss : 0.00217
# Epoch : 200, loss : 0.00135
# Epoch : 300, loss : 0.00084
# Epoch : 400, loss : 0.00035
# Epoch : 500, loss : 0.00011
# Epoch : 600, loss : 0.00003
# Epoch : 700, loss : 0.00001
# Epoch : 800, loss : 0.00001
# Epoch : 900, loss : 0.00001
# Epoch : 1000, loss : 0.00000
# Epoch : 1100, loss : 0.00000
# Epoch : 1200, loss : 0.00000
# Epoch : 1300, loss : 0.00000
# Epoch : 1400, loss : 0.00000
# Epoch : 1500, loss : 0.00000
# Epoch : 1600, loss : 0.00000
# Epoch : 1700, loss : 0.00000
# Epoch : 1800, loss : 0.00000
# Epoch : 1900, loss : 0.00000
# Epoch : 2000, loss : 0.00000
# Epoch : 2100, loss : 0.00000
# Epoch : 2200, loss : 0.00000
# Epoch : 2300, loss : 0.00000
# Epoch : 2400, loss : 0.00000
# Epoch : 2500, loss : 0.00000
# Epoch : 2600, loss : 0.00000
# Epoch : 2700, loss : 0.00000
# Epoch : 2800, loss : 0.00000
# Epoch : 2900, loss : 0.00000
# Epoch : 3000, loss : 0.00000
# Epoch : 3100, loss : 0.00000
# Epoch : 3200, loss : 0.00000
# Epoch : 3300, loss : 0.00000
# Epoch : 3400, loss : 0.00000
# Epoch : 3500, loss : 0.00000
# Epoch : 3600, loss : 0.00000
# Epoch : 3700, loss : 0.00000
# Epoch : 3800, loss : 0.00000
# Epoch : 3900, loss : 0.00000
# Epoch : 4000, loss : 0.00000
# Epoch : 4100, loss : 0.00000
# Epoch : 4200, loss : 0.00000
# Epoch : 4300, loss : 0.00000
# Epoch : 4400, loss : 0.00000
# Epoch : 4500, loss : 0.00000
# Epoch : 4600, loss : 0.00000
# Epoch : 4700, loss : 0.00000
# Epoch : 4800, loss : 0.00000
# Epoch : 4900, loss : 0.00000

# %%
df_x_ss = ss.transform(X)
df_y_ms = ms.transform(y)

df_x_ss = Variable(torch.Tensor(df_x_ss))
df_y_ms = Variable(torch.Tensor(df_y_ms))
df_x_ss = torch.reshape(df_x_ss, (df_x_ss.shape[0], 1, df_x_ss.shape[1]))

# %%
train_predict = model(df_x_ss)
predicted = train_predict.data.numpy()

label_y = df_y_ms.data.numpy()

predicted = ms.inverse_transform(predicted)
label_y = ms.inverse_transform(label_y)
plt.figure(figsize=(10, 6))
# plt.axvline(x=datetime(2022,5,1), c='r', linestyle='--')

df['pred'] = predicted
plt.plot(df['Close'], label='Actual Data')
plt.plot(df['pred'], label='Predicted Data')

plt.title('Time-series Prediction')
plt.legend()
plt.show()

# %% [markdown]
# ## GRU

# %%
class GRU(nn.Module) :
    def __init__(self, num_classes, input_size, hidden_size, num_layers, seq_length) : #초반에 값을 세팅
        super(GRU, self).__init__()
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.gru = nn.GRU(input_size=input_size,hidden_size=hidden_size,
                         num_layers=num_layers,batch_first=True)
        self.fc_1 = nn.Linear(hidden_size, 128)
        self.fc = nn.Linear(128, num_classes) # fc1 , fc : num_classes 가 최종나오는값
        self.relu = nn.ReLU()
        
    def forward(self, x) : # 실제 돌아가는 함수 ,self는 자기자신을 뜻한다. x : 데이터(input),
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))
        output, (hn) = self.gru(x, (h_0)) #hn : GRU에서 나오는 값 ,위에서는 말그래도 세팅이고 여기서 GRU를 돌리는것
        
        hn = hn.view(-1, self.hidden_size)
        out = self.relu(hn) # hn위치에 output을 넣어서 돌려보길 추천!!!!!!!!!!!!!
        out = self.fc_1(out)
        out = self.relu(out)
        out = self.fc(out)
        return out

# %%
num_epochs = 2000
learning_rate = 0.01

input_size=20
hidden_size=40 # 바꿔보기
num_layers=1 # layer 바꿔보기 -> 오식이 베스트 2개

num_classes=1
model=GRU(num_classes,input_size,hidden_size,num_layers,X_train_tensors_f.shape[1])

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs) :
    outputs = model.forward(X_train_tensors_f)
    optimizer.zero_grad()
    loss = criterion(outputs, y_train_tensors)
    loss.backward()
    
    optimizer.step()
    if epoch % 100 == 0 :
        print(f'Epoch : {epoch}, loss : {loss.item():1.5f}')
# Out:
# Epoch : 0, loss : 0.39385
# Epoch : 100, loss : 0.00003
# Epoch : 200, loss : 0.00001
# Epoch : 300, loss : 0.00000
# Epoch : 400, loss : 0.00000
# Epoch : 500, loss : 0.00000
# Epoch : 600, loss : 0.00000
# Epoch : 700, loss : 0.00000
# Epoch : 800, loss : 0.00000
# Epoch : 900, loss : 0.00000
# Epoch : 1000, loss : 0.00000
# Epoch : 1100, loss : 0.00000
# Epoch : 1200, loss : 0.00000
# Epoch : 1300, loss : 0.00000
# Epoch : 1400, loss : 0.00000
# Epoch : 1500, loss : 0.00000
# Epoch : 1600, loss : 0.00000
# Epoch : 1700, loss : 0.00000
# Epoch : 1800, loss : 0.00000
# Epoch : 1900, loss : 0.00000

# %%
df_x_ss = ss.transform(X)
df_y_ms = ms.transform(y)

df_x_ss = Variable(torch.Tensor(df_x_ss))
df_y_ms = Variable(torch.Tensor(df_y_ms))
df_x_ss = torch.reshape(df_x_ss, (df_x_ss.shape[0], 1, df_x_ss.shape[1]))

# %%
train_predict = model(df_x_ss)
predicted = train_predict.data.numpy()

label_y = df_y_ms.data.numpy()

predicted = ms.inverse_transform(predicted)
label_y = ms.inverse_transform(label_y)
plt.figure(figsize=(10, 6))
# plt.axvline(x=datetime(2022,5,1), c='r', linestyle='--')

df['pred'] = predicted
plt.plot(df['Close'], label='Actual Data')
plt.plot(df['pred'], label='Predicted Data')

plt.title('Time-series Prediction')
plt.legend()
plt.show()

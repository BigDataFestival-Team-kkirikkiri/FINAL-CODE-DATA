# %% [markdown]
# # 패키지, 데이터 로드

# %%
# 패키지 로드 
import pandas as pd 
from bs4 import BeautifulSoup  # html 파싱 
import re  # 정규표현식

# %%
# 데이터 로드 
file_path = '../../../data/mirae/2023BigFesta_NewsDataset_202305_5.xlsx'  
news = pd.read_excel(file_path)
news.head() # 확인
# Out:
#    Unnamed: 0  NEWS_YM        DATE_TIME  WRITER SUBCATEGORY  \
# 0       48273   202305  20230502_070122  인베스트조선          경제
# 1       48274   202305  20230502_112220  인베스트조선          경제
# 2       48275   202305  20230503_070107  인베스트조선          경제
# 3       48276   202305  20230503_092206  인베스트조선          경제
# 4       48277   202305  20230504_112909  인베스트조선          기술
#
#                                         TITLE  IMPORTANCE  \
# 0  '쓱페이' 내놓고 '멤버십' 강화하는 신세계…'유동성 확보·밸류 확인' 고민       22.13
# 1               캠코, 1조원 규모 기업구조혁신펀드 운용사 모집 시작       21.30
# 2        보험사 IFRS17 도입 최대 수혜자=빅4 회계법인…커지는 책임론       21.68
# 3                    S&P "한국 기업들, 글로벌 격랑에 직면"       21.26
# 4       카카오, 1분기 영업익 반토막…"그룹 차원 비용 효율화 진행할 것"       68.73
#
#                                  ITEM_NAME  \
# 0                                  이마트|신세계
# 1                                      NaN
# 2  삼성생명|한화생명|동양생명|미래에셋생명|케이디비생명|삼성화재|메리츠화재
# 3                                      NaN
# 4                                      NaN
#
#                                 TAG_LIST  \
# 0                    토스| SSG닷컴| 간편결제| 유통
# 1                                    NaN
# 2                                     책임
# 3                    글로벌| 반도체| 유틸리티| 완성차
# 4  AI| 헬스케어| 데이터센터| 인프라| 인공지능| 클라우드| 글로벌
#
#                                              CONTENT
# 0  <img src="http://img.investchosun.com/site/dat...
# 1  <img src="http://img.investchosun.com/site/dat...
# 2  <img src="http://img.investchosun.com/site/dat...
# 3  <img src="http://img.investchosun.com/site/dat...
# 4  <img src="http://img.investchosun.com/site/dat...

# %%
news.drop('Unnamed: 0',axis = 1, inplace = True) # 불필요한 열 삭제 
news.head() # 확인
# Out:
#    NEWS_YM        DATE_TIME  WRITER SUBCATEGORY  \
# 0   202305  20230502_070122  인베스트조선          경제
# 1   202305  20230502_112220  인베스트조선          경제
# 2   202305  20230503_070107  인베스트조선          경제
# 3   202305  20230503_092206  인베스트조선          경제
# 4   202305  20230504_112909  인베스트조선          기술
#
#                                         TITLE  IMPORTANCE  \
# 0  '쓱페이' 내놓고 '멤버십' 강화하는 신세계…'유동성 확보·밸류 확인' 고민       22.13
# 1               캠코, 1조원 규모 기업구조혁신펀드 운용사 모집 시작       21.30
# 2        보험사 IFRS17 도입 최대 수혜자=빅4 회계법인…커지는 책임론       21.68
# 3                    S&P "한국 기업들, 글로벌 격랑에 직면"       21.26
# 4       카카오, 1분기 영업익 반토막…"그룹 차원 비용 효율화 진행할 것"       68.73
#
#                                  ITEM_NAME  \
# 0                                  이마트|신세계
# 1                                      NaN
# 2  삼성생명|한화생명|동양생명|미래에셋생명|케이디비생명|삼성화재|메리츠화재
# 3                                      NaN
# 4                                      NaN
#
#                                 TAG_LIST  \
# 0                    토스| SSG닷컴| 간편결제| 유통
# 1                                    NaN
# 2                                     책임
# 3                    글로벌| 반도체| 유틸리티| 완성차
# 4  AI| 헬스케어| 데이터센터| 인프라| 인공지능| 클라우드| 글로벌
#
#                                              CONTENT
# 0  <img src="http://img.investchosun.com/site/dat...
# 1  <img src="http://img.investchosun.com/site/dat...
# 2  <img src="http://img.investchosun.com/site/dat...
# 3  <img src="http://img.investchosun.com/site/dat...
# 4  <img src="http://img.investchosun.com/site/dat...

# %% [markdown]
# # CONTENT(뉴스본문)열이 결측치인 행 제거

# %%
sum(news['CONTENT'].isna())
# Out:
# 1

# %%
news = news.dropna(subset=['CONTENT'])

# %% [markdown]
# # 키워드 지정
# - 아래의 키워드를 뉴스 본문 html 이 저장된 변수인 'CONTENT'변수에 2번 이상 포함하지 않을 경우 엔터테인먼트와 무관한 기사로 판단하여 제거한다.

# %%
keywords = [
    '방시혁','하이브','에스엠','이수만','와이지','양현석','제이와이피','박진영',
    
    '뉴진스','방탄소년단','르세라핌',
    '세븐틴','투모로우바이투게더',
    '프로미스나인','나나','이현','미드낫','엔하이픈',
    '백호','강동호','황민현','예하나','성연','지코',
    '앤팀','히라테 유리나','보이넥스트도어',
    
    '블랙핑크','트레저','악뮤','악동뮤지션',
    '위너','지디','권지용',
    '젝스키스',
    
    '트와이스','엔믹스', '데이식스',
    'itzy','채령','류진','유나','예지'
    
    '스트레이키즈','투피엠','보이스토리',
    '야오천','니지유','엑스디너리 히어로즈',
    'boa',
    '에스파',
    '엑소',
    
    '샤이니','엔시티','엔시티 127','엔시티 드림',    
    '동방신기','슈퍼주니어','소녀시대','엑소'
    '레드벨벳','웨이션브이','슈퍼엠',
    '갓더비트','갓 더 비트','라이즈'

]

# 특정 단어 목록을 정규식 패턴으로 변환
keywords_pattern = '|'.join(keywords)

# 'PARSED CONTENT' 열에서 정규식 패턴을 검색하여 추출
filtered_df = news[news['CONTENT'].str.contains(keywords_pattern, flags=re.IGNORECASE, regex=True)]

# 특정 키워드가 2번 이상 포함된 행만 남기기
filtered_df = filtered_df[filtered_df['CONTENT'].apply(lambda text: sum(1 for keyword in keywords if keyword.lower() in text.lower()) >= 2)]

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 76 to 228374
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NEWS_YM      2426 non-null   int64
#  1   DATE_TIME    2426 non-null   object
#  2   WRITER       2426 non-null   object
#  3   SUBCATEGORY  2426 non-null   object
#  4   TITLE        2426 non-null   object
#  5   IMPORTANCE   2426 non-null   float64
#  6   ITEM_NAME    1029 non-null   object
#  7   TAG_LIST     1938 non-null   object
#  8   CONTENT      2426 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 189.5+ KB

# %% [markdown]
# # 데이터 저장

# %%
# 데이터 저장
file_path = '../../../data/News/news_1filtered_202305.xlsx'  
filtered_df.to_excel(file_path, index=False)

# %% [markdown]
# # 패키지, 데이터 로드

# %%
# 패키지 로드 
import pandas as pd 
from bs4 import BeautifulSoup  # html 파싱 
import re  # 정규표현식

# %%
# 데이터 로드 
file_path = '../../../data/mirae/2023BigFesta_NewsDataset_202301_5.xlsx'  
news = pd.read_excel(file_path)
news.head() # 확인
# Out:
#    Unnamed: 0  NEWS_YM        DATE_TIME WRITER SUBCATEGORY  \
# 0        5776   202301  20230101_005758  머니투데이          사회
# 1        5777   202301  20230101_060000  머니투데이          정치
# 2        5778   202301  20230101_061000  머니투데이          사회
# 3        5779   202301  20230101_070300  머니투데이          경제
# 4        5780   202301  20230101_073000  머니투데이          사회
#
#                                   TITLE  IMPORTANCE ITEM_NAME  \
# 0       "친구야 새해엔 합격하자"…보신각서 새해 맞이한 10만명       76.09       NaN
# 1          오세훈 시장, 계묘년 새해 맞아 국립서울현충원 참배       43.47       NaN
# 2  [더영상] 눈사람 훔치면 절도죄?…美 '괴물 눈폭풍' 57명 사망       68.08       NaN
# 3      "이미 모든 악재 나왔다"…전문가가 뽑은 내년 뜰 업종은?       58.26   고려아연|영풍
# 4                 [사진]2023년 계묘년(癸卯年) 새해       30.14       NaN
#
#                                TAG_LIST  \
# 0                             경찰| 코로나19
# 1                                   NaN
# 2         경찰| 프랜차이즈| SNS| 소셜네트워크서비스| 마약
# 3  건설| 반도체| 2차전지| 은행| 부동산| 자동차| 인터넷| 부실
# 4                                   NaN
#
#                                              CONTENT
# 0  [머니투데이 김도균 기자, 김미루 기자] <img src="http://thumb....
# 1  [머니투데이 기성훈 기자] <img src="http://thumb.mt.co.kr...
# 2  [머니투데이 차유채 기자] [편집자주] 한 주간 온라인을 달궜던 동영상들을 소개합니...
# 3  [머니투데이 홍순빈 기자] [[2023 증시 전망]국내 증시 주목할 업종]_x000...
# 4  [머니투데이 홍봉진 기자] <img src="http://thumb.mt.co.kr...

# %%
news.drop('Unnamed: 0',axis = 1, inplace = True) # 불필요한 열 삭제 
news.head() # 확인
# Out:
#    NEWS_YM        DATE_TIME WRITER SUBCATEGORY  \
# 0   202301  20230101_005758  머니투데이          사회
# 1   202301  20230101_060000  머니투데이          정치
# 2   202301  20230101_061000  머니투데이          사회
# 3   202301  20230101_070300  머니투데이          경제
# 4   202301  20230101_073000  머니투데이          사회
#
#                                   TITLE  IMPORTANCE ITEM_NAME  \
# 0       "친구야 새해엔 합격하자"…보신각서 새해 맞이한 10만명       76.09       NaN
# 1          오세훈 시장, 계묘년 새해 맞아 국립서울현충원 참배       43.47       NaN
# 2  [더영상] 눈사람 훔치면 절도죄?…美 '괴물 눈폭풍' 57명 사망       68.08       NaN
# 3      "이미 모든 악재 나왔다"…전문가가 뽑은 내년 뜰 업종은?       58.26   고려아연|영풍
# 4                 [사진]2023년 계묘년(癸卯年) 새해       30.14       NaN
#
#                                TAG_LIST  \
# 0                             경찰| 코로나19
# 1                                   NaN
# 2         경찰| 프랜차이즈| SNS| 소셜네트워크서비스| 마약
# 3  건설| 반도체| 2차전지| 은행| 부동산| 자동차| 인터넷| 부실
# 4                                   NaN
#
#                                              CONTENT
# 0  [머니투데이 김도균 기자, 김미루 기자] <img src="http://thumb....
# 1  [머니투데이 기성훈 기자] <img src="http://thumb.mt.co.kr...
# 2  [머니투데이 차유채 기자] [편집자주] 한 주간 온라인을 달궜던 동영상들을 소개합니...
# 3  [머니투데이 홍순빈 기자] [[2023 증시 전망]국내 증시 주목할 업종]_x000...
# 4  [머니투데이 홍봉진 기자] <img src="http://thumb.mt.co.kr...

# %% [markdown]
# # 키워드 지정
# - 아래의 키워드를 뉴스 본문 html 이 저장된 변수인 'CONTENT'변수에 2번 이상 포함하지 않을 경우 엔터테인먼트와 무관한 기사로 판단하여 제거한다.

# %%
keywords = [
    '방시혁','하이브','에스엠','이수만','와이지','양현석','제이와이피','박진영',
    
    '뉴진스','방탄소년단','르세라핌',
    '세븐틴','투모로우바이투게더',
    '프로미스나인','나나','이현','미드낫','엔하이픈',
    '백호','강동호','황민현','예하나','성연','지코',
    '앤팀','히라테 유리나','보이넥스트도어',
    
    '블랙핑크','트레저','악뮤','악동뮤지션',
    '위너','지디','권지용',
    '젝스키스',
    
    '트와이스','엔믹스', '데이식스',
    'itzy','채령','류진','유나','예지'
    
    '스트레이키즈','투피엠','보이스토리',
    '야오천','니지유','엑스디너리 히어로즈',
    'boa',
    '에스파',
    '엑소',
    
    '샤이니','엔시티','엔시티 127','엔시티 드림',    
    '동방신기','슈퍼주니어','소녀시대','엑소'
    '레드벨벳','웨이션브이','슈퍼엠',
    '갓더비트','갓 더 비트','라이즈'

]

# 특정 단어 목록을 정규식 패턴으로 변환
keywords_pattern = '|'.join(keywords)

# 'CONTENT'(뉴스 본문)열에서 정규식 패턴을 검색하여 추출
filtered_df = news[news['CONTENT'].str.contains(keywords_pattern, flags=re.IGNORECASE, regex=True)]

# 특정 키워드가 2번 이상 포함된 행만 남기기
filtered_df = filtered_df[filtered_df['CONTENT'].apply(lambda text: sum(1 for keyword in keywords if keyword.lower() in text.lower()) >= 2)]

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2489 entries, 58 to 228157
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NEWS_YM      2489 non-null   int64
#  1   DATE_TIME    2489 non-null   object
#  2   WRITER       2489 non-null   object
#  3   SUBCATEGORY  2489 non-null   object
#  4   TITLE        2489 non-null   object
#  5   IMPORTANCE   2489 non-null   float64
#  6   ITEM_NAME    951 non-null    object
#  7   TAG_LIST     1558 non-null   object
#  8   CONTENT      2489 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 194.5+ KB

# %% [markdown]
# # 데이터 저장

# %%
# 데이터 저장
file_path = '../../../data/News/news_1filtered_202301.xlsx'  
filtered_df.to_excel(file_path, index=False)

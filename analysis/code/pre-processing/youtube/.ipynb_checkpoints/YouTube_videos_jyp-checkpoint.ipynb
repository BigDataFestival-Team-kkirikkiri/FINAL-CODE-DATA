# %% [markdown]
# # (0) 필요한 모듈

# %%
#!pip install google-api-python-client

#YOUTUBE OPEN API 관련 모듈
from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

#기타 모듈
import pandas as pd
import numpy as np
import re #문자열 패턴 관련 모듈
import requests
import os

# %%
#현재 working directory 경로 확인
#코드 실행자의 파일 위치에 따라 달라짐
os.getcwd()
# Out:
# '/Users/yusolcho/Desktop/analysis/code/pre-processing/youtube'

# %% [markdown]
# <span style = "color:Red;">**!!!주의 사항!!!**</span>
#
# (1) YouTube OPEN API 사용 시, 구글 클라우드 플랫폼에 연결되어 있는 상태인지 확인 필요함. 안 그러면 에러 발생.
# <br>=> 구글 클라우드 플랫폼 사이트에서 구글 계정으로 로그인 된 상태에서 '콘솔' 클릭하여 활성화해야 함.
#
# (2) OPEN API로 불러온 데이터는 가능한한 저장을 권장함.
# <br>=> 하루 할당량(=약 10,000)이 있기 때문에...

# %% [markdown]
# # (1) 채널 id 데이터프레임 불러오기
# Search: list 리소스를 사용하여 추출한 채널 id 데이터프레임 파일 불러오기

# %%
channel = pd.read_csv("../../../data/YouTube/channel_jyp.csv")
channel
# Out:
#              channel                channel_id
# 0  JYP Entertainment  UCaO6TYtlC8U5ttz62hTrZgg
# 1         Stray Kids  UCDhM2k2Cua-JdobAh5moMFg
# 2              TWICE  UCDhM2k2Cua-JdobAh5moMFg
# 3              NMIXX  UCDhM2k2Cua-JdobAh5moMFg
# 4               DAY6  UCTP45_DE3fMLujU8sZ-MBzw
# 5               ITZY  UCDhM2k2Cua-JdobAh5moMFg

# %% [markdown]
# # (2) 업로드 재생목록 id 추출
# Channels: list 리소스를 사용함.

# %% [markdown]
# ## (2-1) 채널당 재생목록 id 추출

# %% [markdown]
# **!!업로드 재생목록은 채널당 딱 하나만 나옴**

# %%
#기본 정보 설정
api_key = "AIzaSyCR_i3URXYE3p_g_KW5K0PFzXvIXpiAbYk" #api key는 보안상의 문제로 마킹 처리함
youtube_api_service_name = "youtube" #Google API 객체를 생성 (명칭은 'youtube'로 고정됨)
youtube_api_version = "v3"
youtube = build(youtube_api_service_name, youtube_api_version, developerKey=api_key)

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][0] #JYP Entertainment 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'wnjwrnYJQLTe9-aM3ZYXlPDQPdg',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'PU-uaxxAB95m5arS3QeaDss7Q1Q',
#    'id': 'UCaO6TYtlC8U5ttz62hTrZgg',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUaO6TYtlC8U5ttz62hTrZgg'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_jyp = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_jyp
# Out:
# 'UUaO6TYtlC8U5ttz62hTrZgg'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][1] #Stray Kids 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '71Wjpp12HwjgBkakK2arf2whyW4',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'DEYW-CuZwhj7MQAyzvQotYEt8vg',
#    'id': 'UCDhM2k2Cua-JdobAh5moMFg',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUDhM2k2Cua-JdobAh5moMFg'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_straykids = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_straykids
# Out:
# 'UUDhM2k2Cua-JdobAh5moMFg'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][2] #TWICE 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '71Wjpp12HwjgBkakK2arf2whyW4',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'DEYW-CuZwhj7MQAyzvQotYEt8vg',
#    'id': 'UCDhM2k2Cua-JdobAh5moMFg',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUDhM2k2Cua-JdobAh5moMFg'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_twice = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_twice
# Out:
# 'UUDhM2k2Cua-JdobAh5moMFg'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][3] #NMIXX 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '71Wjpp12HwjgBkakK2arf2whyW4',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'DEYW-CuZwhj7MQAyzvQotYEt8vg',
#    'id': 'UCDhM2k2Cua-JdobAh5moMFg',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUDhM2k2Cua-JdobAh5moMFg'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_nmixx = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_nmixx
# Out:
# 'UUDhM2k2Cua-JdobAh5moMFg'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][4] #DAY6 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'pvDlL07QbjKarsVWvkspEDWHie0',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '1O1l3Tc1ot0xcEpzEtAzu8vW_5E',
#    'id': 'UCTP45_DE3fMLujU8sZ-MBzw',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUTP45_DE3fMLujU8sZ-MBzw'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_day6 = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_day6
# Out:
# 'UUTP45_DE3fMLujU8sZ-MBzw'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][5] #ITZY 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '71Wjpp12HwjgBkakK2arf2whyW4',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'DEYW-CuZwhj7MQAyzvQotYEt8vg',
#    'id': 'UCDhM2k2Cua-JdobAh5moMFg',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUDhM2k2Cua-JdobAh5moMFg'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_itzy = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_itzy
# Out:
# 'UUDhM2k2Cua-JdobAh5moMFg'

# %% [markdown]
# ## (2-2) 데이터프레임으로 저장
# 채널 id 데이터프레임에 추가하여 저장

# %%
channel["playlist_id"] = [pl_jyp, pl_straykids, pl_twice, pl_nmixx, pl_day6, pl_itzy]
channel
# Out:
#              channel                channel_id               playlist_id
# 0  JYP Entertainment  UCaO6TYtlC8U5ttz62hTrZgg  UUaO6TYtlC8U5ttz62hTrZgg
# 1         Stray Kids  UCDhM2k2Cua-JdobAh5moMFg  UUDhM2k2Cua-JdobAh5moMFg
# 2              TWICE  UCDhM2k2Cua-JdobAh5moMFg  UUDhM2k2Cua-JdobAh5moMFg
# 3              NMIXX  UCDhM2k2Cua-JdobAh5moMFg  UUDhM2k2Cua-JdobAh5moMFg
# 4               DAY6  UCTP45_DE3fMLujU8sZ-MBzw  UUTP45_DE3fMLujU8sZ-MBzw
# 5               ITZY  UCDhM2k2Cua-JdobAh5moMFg  UUDhM2k2Cua-JdobAh5moMFg

# %%
#channel를 csv파일로 저장
channel.to_csv("../../../data/YouTube/channel+pl_jyp.csv", index=False)

# %% [markdown]
# # (3) 재생목록 내 동영상 리스트 및 id 추출
# PlaylistItems: list 리소스를 사용함.

# %%
channel = pd.read_csv("../../../data/YouTube/channel+pl_jyp.csv")
channel
# Out:
#              channel                channel_id               playlist_id
# 0  JYP Entertainment  UCaO6TYtlC8U5ttz62hTrZgg  UUaO6TYtlC8U5ttz62hTrZgg
# 1         Stray Kids  UCDhM2k2Cua-JdobAh5moMFg  UUDhM2k2Cua-JdobAh5moMFg
# 2              TWICE  UCDhM2k2Cua-JdobAh5moMFg  UUDhM2k2Cua-JdobAh5moMFg
# 3              NMIXX  UCDhM2k2Cua-JdobAh5moMFg  UUDhM2k2Cua-JdobAh5moMFg
# 4               DAY6  UCTP45_DE3fMLujU8sZ-MBzw  UUTP45_DE3fMLujU8sZ-MBzw
# 5               ITZY  UCDhM2k2Cua-JdobAh5moMFg  UUDhM2k2Cua-JdobAh5moMFg

# %% [markdown]
# ### (1번) JYP Entertainment
# 제이와이피 JYP

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][0], #JYP Entertainment 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0                     [Nizi Project Season 2] Part 1 #8  Wzt1nH-w3qM
# 1          [Nizi Project Season 2] Part 1 #6（Edit Ver.）  KKRCxN502xw
# 2          A2K ep.17 "Individual Performances Continue"  iKlSlIADqH4
# 3          [Nizi Project Season 2] Part 1 #8 Highlights  -W88xFcqVdA
# 4     A2K ep.16 "Korean Boot Camp Begins" AFTERPARTY...  tSuk4sNDWIw
# ...                                                 ...          ...
# 1816                               Wonder Girls _ Yubin  ZKhWdYNUQ08
# 1817                        Wonder Girls "Take it!" M/V  GP3e9HahVxw
# 1818                             J.Y.Park with Lil Jon!  jDBuseb0RWU
# 1819                          Wonder Girls "Stupid" M/V  rdclb6oQO94
# 1820                         Wonder Girls "Tell me" M/V  BlHv3BbBv6A
#
# [1821 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_jyp.csv", index=False)

# %% [markdown]
# ### (2번) Stray Kids
# 스트레이키즈

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][1], #Stray Kids 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #YU...  -CsZf2-q7P4
# 1     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #CH...  FVkcymuFZTM
# 2     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #RY...  SIAc66A9sFw
# 3     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #LI...  _sZJa8xWk24
# 4     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #YE...  vw2NhmZhv4Q
# ...                                                 ...          ...
# 1239         ITZY "달라달라(DALLA DALLA)" : M/V BEHIND #Lia  1b_-JQLgjM8
# 1240        ITZY "달라달라(DALLA DALLA)" : M/V BEHIND #Yeji  BTHJ_88r9C8
# 1241       ITZY "IT'z Different" : PROLOGUE FILM BEHIND  QD7CFo7G_hI
# 1242      ITZY "IT'z Different" : THE PHOTOSHOOT BEHIND  hKAdYiaYgHo
# 1243                         To. ITZY, From. JYP Family  ugjXALzjEBo
#
# [1244 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_straykids.csv", index=False)

# %% [markdown]
# ### (3번) TWICE
# 트와이스

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][2], #TWICE 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #YU...  -CsZf2-q7P4
# 1     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #CH...  FVkcymuFZTM
# 2     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #RY...  SIAc66A9sFw
# 3     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #LI...  _sZJa8xWk24
# 4     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #YE...  vw2NhmZhv4Q
# ...                                                 ...          ...
# 1239         ITZY "달라달라(DALLA DALLA)" : M/V BEHIND #Lia  1b_-JQLgjM8
# 1240        ITZY "달라달라(DALLA DALLA)" : M/V BEHIND #Yeji  BTHJ_88r9C8
# 1241       ITZY "IT'z Different" : PROLOGUE FILM BEHIND  QD7CFo7G_hI
# 1242      ITZY "IT'z Different" : THE PHOTOSHOOT BEHIND  hKAdYiaYgHo
# 1243                         To. ITZY, From. JYP Family  ugjXALzjEBo
#
# [1244 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_twice.csv", index=False)

# %% [markdown]
# ### (4번) NMIXX
# 엔믹스

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][3], #NMIXX 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #YU...  -CsZf2-q7P4
# 1     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #CH...  FVkcymuFZTM
# 2     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #RY...  SIAc66A9sFw
# 3     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #LI...  _sZJa8xWk24
# 4     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #YE...  vw2NhmZhv4Q
# ...                                                 ...          ...
# 1239         ITZY "달라달라(DALLA DALLA)" : M/V BEHIND #Lia  1b_-JQLgjM8
# 1240        ITZY "달라달라(DALLA DALLA)" : M/V BEHIND #Yeji  BTHJ_88r9C8
# 1241       ITZY "IT'z Different" : PROLOGUE FILM BEHIND  QD7CFo7G_hI
# 1242      ITZY "IT'z Different" : THE PHOTOSHOOT BEHIND  hKAdYiaYgHo
# 1243                         To. ITZY, From. JYP Family  ugjXALzjEBo
#
# [1244 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_nmixx.csv", index=False)

# %% [markdown]
# ### (5번) DAY6
# 데이식스

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][4], #DAY6 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                           video_title     video_id
# 0    Trust Me (MIDZY) -Japanese ver.-  w3I5zfyEbbo
# 1                           Kill Shot  sMF6BpG3esI
# 2                 None of My Business  iUqsts7GoUA
# 3                       Psychic Lover  WKNHe60epck
# 4                           BET ON ME  jKcWfFe2XNE
# ..                                ...          ...
# 168                               ICY  ZpD59tu5_Rk
# 169  달라달라 (DallasK Remix) DALLA DALLA  fw8l3YUpae8
# 170                       IT'z SUMMER  b1hyjSA4ONc
# 171                          WANT IT?  UMfJoFnR4Ew
# 172                  달라달라 DALLA DALLA  miqQAzOXPBo
#
# [173 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_day6.csv", index=False)

# %% [markdown]
# ### (6번) ITZY
# 있지

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][5], #ITZY 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #YU...  -CsZf2-q7P4
# 1     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #CH...  FVkcymuFZTM
# 2     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #RY...  SIAc66A9sFw
# 3     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #LI...  _sZJa8xWk24
# 4     ITZY OFFICIAL FANCLUB MIDZY 3RD GENERATION #YE...  vw2NhmZhv4Q
# ...                                                 ...          ...
# 1239         ITZY "달라달라(DALLA DALLA)" : M/V BEHIND #Lia  1b_-JQLgjM8
# 1240        ITZY "달라달라(DALLA DALLA)" : M/V BEHIND #Yeji  BTHJ_88r9C8
# 1241       ITZY "IT'z Different" : PROLOGUE FILM BEHIND  QD7CFo7G_hI
# 1242      ITZY "IT'z Different" : THE PHOTOSHOOT BEHIND  hKAdYiaYgHo
# 1243                         To. ITZY, From. JYP Family  ugjXALzjEBo
#
# [1244 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_itzy.csv", index=False)

# %% [markdown]
# # (4) 동영상 데이터 추출
# Videos: list 리소스를 사용함.

# %% [markdown]
# <span style = "color:Red;">**!!!주의 사항!!!**</span>
#
# 이 단계에서는 요청량이 많아서 API 요청이 끊길 수 있음!!
# <br>적당히 데이터량 조절하면서 보는게 좋을 수도!!
# <br>여기선 무조건 저장 필수!!!!!!!!

# %% [markdown]
# ### (1번) JYP Entertainment
# 제이와이피(JYP)

# %%
item_jyp = pd.read_csv("../../../data/YouTube/item_jyp.csv")
item_jyp
# Out:
#                                             video_title     video_id
# 0                     [Nizi Project Season 2] Part 1 #8  Wzt1nH-w3qM
# 1          [Nizi Project Season 2] Part 1 #6（Edit Ver.）  KKRCxN502xw
# 2          A2K ep.17 "Individual Performances Continue"  iKlSlIADqH4
# 3          [Nizi Project Season 2] Part 1 #8 Highlights  -W88xFcqVdA
# 4     A2K ep.16 "Korean Boot Camp Begins" AFTERPARTY...  tSuk4sNDWIw
# ...                                                 ...          ...
# 1816                               Wonder Girls _ Yubin  ZKhWdYNUQ08
# 1817                        Wonder Girls "Take it!" M/V  GP3e9HahVxw
# 1818                             J.Y.Park with Lil Jon!  jDBuseb0RWU
# 1819                          Wonder Girls "Stupid" M/V  rdclb6oQO94
# 1820                         Wonder Girls "Tell me" M/V  BlHv3BbBv6A
#
# [1821 rows x 2 columns]

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_jyp)): #JYP Entertainment
    request = youtube.videos().list(
        id = item_jyp["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df
# Out:
#                                                   title      videoId  \
# 0                     [Nizi Project Season 2] Part 1 #8  Wzt1nH-w3qM
# 1          [Nizi Project Season 2] Part 1 #6（Edit Ver.）  KKRCxN502xw
# 2          A2K ep.17 "Individual Performances Continue"  iKlSlIADqH4
# 3          [Nizi Project Season 2] Part 1 #8 Highlights  -W88xFcqVdA
# 4     A2K ep.16 "Korean Boot Camp Begins" AFTERPARTY...  tSuk4sNDWIw
# ...                                                 ...          ...
# 1816                               Wonder Girls _ Yubin  ZKhWdYNUQ08
# 1817                        Wonder Girls "Take it!" M/V  GP3e9HahVxw
# 1818                             J.Y.Park with Lil Jon!  jDBuseb0RWU
# 1819                          Wonder Girls "Stupid" M/V  rdclb6oQO94
# 1820                         Wonder Girls "Tell me" M/V  BlHv3BbBv6A
#
#             date categoryId      view    like dislike comment  \
# 0     2023-09-08         10     77075    4726       -     486
# 1     2023-09-08         10    194465    3413       -     550
# 2     2023-09-08         10   1356234   58038       -    6029
# 3     2023-09-05         10    126242    2394       -     134
# 4     2023-09-05         10         -    6065       -     600
# ...          ...        ...       ...     ...     ...     ...
# 1816  2008-01-29         24    133654    1150       -     147
# 1817  2008-01-28         24   3050716    5899       -     939
# 1818  2008-01-28         24    154248    1267       -     229
# 1819  2008-01-28         24   2525260   10109       -    1344
# 1820  2008-01-28         24  33271925  808373       -   30042
#
#                                                    tags hour min sec
# 0     JYP Entertainment|JYP|Globalaudition|Audition|...    -  50  27
# 1     JYP Entertainment|JYP|Globalaudition|Audition|...    -  49   3
# 2     JYP Entertainment|JYP|A2K|America2Korea|Republ...    -  45  28
# 3     JYP Entertainment|JYP|Globalaudition|Audition|...    -   1   9
# 4     JYP Entertainment|JYP|A2K|America2Korea|Republ...    -   6  21
# ...                                                 ...  ...  ..  ..
# 1816                             Wonder|Girls|Yubin|Rap    -   1  10
# 1817  Wonder|Girls|Take|it|박진영|원더걸스|2AM|2PM|JOO|Joon...    -   3  44
# 1818  jyp|lil|jon|j.y.park|박진영|korea|원더걸스|2AM|2PM|JO...    -   4  17
# 1819  Wonder|Girls|Stupid|박진영|원더걸스|2AM|2PM|JOO|JoonP...    -   3  59
# 1820  Wonder|Girls|Tell|me|irony|박진영|원더걸스|2AM|2PM|JO...    -   4   8
#
# [1821 rows x 12 columns]

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_jyp.csv", index=False)

# %% [markdown]
# ### (2번) Stray Kids
# 스트레이키즈

# %%
item_straykids = pd.read_csv("../../../data/YouTube/item_straykids.csv")
item_straykids
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [126], in <cell line: 1>()
# ----> 1 item_straykids = pd.read_csv("../../../data/YouTube/item_straykids.csv")
#       2 item_straykids
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_straykids)): #Stray Kids
    request = youtube.videos().list(
        id = item_straykids["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_straykids.csv", index=False)

# %% [markdown]
# ### (3번) TWICE
# 트와이스

# %%
item_twice = pd.read_csv("../../../data/YouTube/item_twice.csv")
item_twice

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_twice)): #TWICE
    request = youtube.videos().list(
        id = item_twice["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_twice.csv", index=False)

# %% [markdown]
# ### (4번) NMIXX
# 엔믹스

# %%
item_nmixx = pd.read_csv("../../../data/YouTube/item_nmixx.csv")
item_nmixx

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_nmixx)): #NMIXX
    request = youtube.videos().list(
        id = item_nmixx["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_nmixx.csv", index=False)

# %% [markdown]
# ### (5번) DAY6
# 데이식스

# %%
item_day6 = pd.read_csv("../../../data/YouTube/item_day6.csv")
item_day6

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_day6)): #DAY6
    request = youtube.videos().list(
        id = item_day6["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_day6.csv", index=False)

# %% [markdown]
# ### (6번) ITZY
# 있지

# %%
item_itzy = pd.read_csv("../../../data/YouTube/item_itzy.csv")
item_itzy

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_itzy)): #ITZY
    request = youtube.videos().list(
        id = item_itzy["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_itzy.csv", index=False)

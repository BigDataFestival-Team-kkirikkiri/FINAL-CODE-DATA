# %% [markdown]
# # (0) 필요한 모듈

# %%
#!pip install google-api-python-client

#YOUTUBE OPEN API 관련 모듈
from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

#기타 모듈
import pandas as pd
import numpy as np
import re #문자열 패턴 관련 모듈
import requests
import os

# %%
#현재 working directory 경로 확인
#코드 실행자의 파일 위치에 따라 달라짐
os.getcwd()
# Out:
# '/Users/yusolcho/Desktop/analysis/code/pre-processing/youtube'

# %% [markdown]
# <span style = "color:Red;">**!!!주의 사항!!!**</span>
#
# (1) YouTube OPEN API 사용 시, 구글 클라우드 플랫폼에 연결되어 있는 상태인지 확인 필요함. 안 그러면 에러 발생.
# <br>=> 구글 클라우드 플랫폼 사이트에서 구글 계정으로 로그인 된 상태에서 '콘솔' 클릭하여 활성화해야 함.
#
# (2) OPEN API로 불러온 데이터는 가능한한 저장을 권장함.
# <br>=> 하루 할당량(=약 10,000)이 있기 때문에

# %% [markdown]
# # (1) 채널 id 데이터프레임 불러오기
# Search: list 리소스를 사용하여 추출한 채널 id 데이터프레임 파일 불러오기

# %%
channel = pd.read_csv("../../../data/YouTube/channel_hybe.csv")
channel
# Out:
#                         channel                channel_id
# 0                   HYBE LABELS  UC3IZKseVpdzPSBaWxBxundA
# 1                      NewJeans  UCfkXDY7vwkcJ8ddFGz8KusA
# 2                     BANGTANTV  UCfkXDY7vwkcJ8ddFGz8KusA
# 3                   LE SSERAFIM  UCfkXDY7vwkcJ8ddFGz8KusA
# 4                     SEVENTEEN  UCfkXDY7vwkcJ8ddFGz8KusA
# 5  TOMORROW X TOGETHER OFFICIAL  UCfkXDY7vwkcJ8ddFGz8KusA

# %% [markdown]
# # (2) 업로드 재생목록 id 추출
# Channels: list 리소스를 사용함.

# %% [markdown]
# ## (2-1) 채널당 재생목록 id 추출

# %% [markdown]
# **!!업로드 재생목록은 채널당 딱 하나만 나옴**

# %%
#기본 정보 설정
api_key = "AIzaSyCR_i3URXYE3p_g_KW5K0PFzXvIXpiAbYk" #api key는 보안상의 문제로 마킹 처리함
youtube_api_service_name = "youtube" #Google API 객체를 생성 (명칭은 'youtube'로 고정됨)
youtube_api_version = "v3"
youtube = build(youtube_api_service_name, youtube_api_version, developerKey=api_key)

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][0] #HYBE LABELS 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '8JUBXKc0TyiDowEPoS7_RdRqH5s',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'eqHI9KgIRtNaqHL0pP2TWJCZZVg',
#    'id': 'UC3IZKseVpdzPSBaWxBxundA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU3IZKseVpdzPSBaWxBxundA'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_hybe = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_hybe
# Out:
# 'UU3IZKseVpdzPSBaWxBxundA'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][1] #NewJeans 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'FPHmi1-d3T7bftQ8gcvV_iKFaBY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '3WjdTr0olDQ9weqVH6GvsB4VFyk',
#    'id': 'UCfkXDY7vwkcJ8ddFGz8KusA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUfkXDY7vwkcJ8ddFGz8KusA'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_newjeans = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_newjeans
# Out:
# 'UUfkXDY7vwkcJ8ddFGz8KusA'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][2] #BANGTANTV 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'FPHmi1-d3T7bftQ8gcvV_iKFaBY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '3WjdTr0olDQ9weqVH6GvsB4VFyk',
#    'id': 'UCfkXDY7vwkcJ8ddFGz8KusA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUfkXDY7vwkcJ8ddFGz8KusA'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_bts = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_bts
# Out:
# 'UUfkXDY7vwkcJ8ddFGz8KusA'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][3] #LE SSERAFIM 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'FPHmi1-d3T7bftQ8gcvV_iKFaBY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '3WjdTr0olDQ9weqVH6GvsB4VFyk',
#    'id': 'UCfkXDY7vwkcJ8ddFGz8KusA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUfkXDY7vwkcJ8ddFGz8KusA'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_lesserafim = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_lesserafim
# Out:
# 'UUfkXDY7vwkcJ8ddFGz8KusA'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][4] #SEVENTEEN 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'FPHmi1-d3T7bftQ8gcvV_iKFaBY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '3WjdTr0olDQ9weqVH6GvsB4VFyk',
#    'id': 'UCfkXDY7vwkcJ8ddFGz8KusA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUfkXDY7vwkcJ8ddFGz8KusA'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_seventeen = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_seventeen
# Out:
# 'UUfkXDY7vwkcJ8ddFGz8KusA'

# %%
#query문 작성
search_response = youtube.channels().list(
    part = "contentDetails",
    maxResults = 50,
    id = channel["channel_id"][5] #TOMORROW X TOGETHER OFFICIAL 채널
).execute()

# %%
search_response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'FPHmi1-d3T7bftQ8gcvV_iKFaBY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '3WjdTr0olDQ9weqVH6GvsB4VFyk',
#    'id': 'UCfkXDY7vwkcJ8ddFGz8KusA',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUfkXDY7vwkcJ8ddFGz8KusA'}}}]}

# %%
#해당 채널에 업로드된 모든 동영상들의 재생목록(playlist)
pl_txt = search_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
pl_txt
# Out:
# 'UUfkXDY7vwkcJ8ddFGz8KusA'

# %% [markdown]
# ## (2-2) 데이터프레임으로 저장
# 채널 id 데이터프레임에 추가하여 저장

# %%
channel["playlist_id"] = [pl_hybe, pl_newjeans, pl_bts, pl_lesserafim, pl_seventeen, pl_txt]
channel
# Out:
#                         channel                channel_id  \
# 0                   HYBE LABELS  UC3IZKseVpdzPSBaWxBxundA
# 1                      NewJeans  UCfkXDY7vwkcJ8ddFGz8KusA
# 2                     BANGTANTV  UCfkXDY7vwkcJ8ddFGz8KusA
# 3                   LE SSERAFIM  UCfkXDY7vwkcJ8ddFGz8KusA
# 4                     SEVENTEEN  UCfkXDY7vwkcJ8ddFGz8KusA
# 5  TOMORROW X TOGETHER OFFICIAL  UCfkXDY7vwkcJ8ddFGz8KusA
#
#                 playlist_id
# 0  UU3IZKseVpdzPSBaWxBxundA
# 1  UUfkXDY7vwkcJ8ddFGz8KusA
# 2  UUfkXDY7vwkcJ8ddFGz8KusA
# 3  UUfkXDY7vwkcJ8ddFGz8KusA
# 4  UUfkXDY7vwkcJ8ddFGz8KusA
# 5  UUfkXDY7vwkcJ8ddFGz8KusA

# %%
#channel를 csv파일로 저장
channel.to_csv("../../../data/YouTube/channel+pl_hybe.csv", index=False)

# %% [markdown]
# # (3) 재생목록 내 동영상 리스트 및 id 추출
# PlaylistItems: list 리소스를 사용함.

# %%
channel = pd.read_csv("../../../data/YouTube/channel+pl_hybe.csv")
channel
# Out:
#                         channel                channel_id  \
# 0                   HYBE LABELS  UC3IZKseVpdzPSBaWxBxundA
# 1                      NewJeans  UCfkXDY7vwkcJ8ddFGz8KusA
# 2                     BANGTANTV  UCfkXDY7vwkcJ8ddFGz8KusA
# 3                   LE SSERAFIM  UCfkXDY7vwkcJ8ddFGz8KusA
# 4                     SEVENTEEN  UCfkXDY7vwkcJ8ddFGz8KusA
# 5  TOMORROW X TOGETHER OFFICIAL  UCfkXDY7vwkcJ8ddFGz8KusA
#
#                 playlist_id
# 0  UU3IZKseVpdzPSBaWxBxundA
# 1  UUfkXDY7vwkcJ8ddFGz8KusA
# 2  UUfkXDY7vwkcJ8ddFGz8KusA
# 3  UUfkXDY7vwkcJ8ddFGz8KusA
# 4  UUfkXDY7vwkcJ8ddFGz8KusA
# 5  UUfkXDY7vwkcJ8ddFGz8KusA

# %% [markdown]
# ### (1번) HYBE LABELS
# 하이브

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][0], #HYBE LABELS 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0                          V 'Slow Dancing' Official MV  eI0iTRS0Ha8
# 1                      V 'Slow Dancing' Official Teaser  mJ1NFKfTF9M
# 2     [HYBE x Geffen] Dream Academy - Mission 1 "Dan...  KVzm2wmG6lU
# 3     [HYBE x Geffen] Dream Academy - Mission 1 "Sti...  1pO6_BCH1kM
# 4     [HYBE x Geffen] Dream Academy - Mission 1 "Pin...  JrK_KV0_zwg
# ...                                                 ...          ...
# 1414                         에이트(8eight) 윤도현의 러브레터 연습현장  WQiNfk8qk_o
# 1415              8eight "I love you (feat.Jessica)" MV  _i99DG6AiLQ
# 1416                                  Bananagirl "S" MV  GJRYr-SMaCo
# 1417                   8eight "Forget Love and Sing" MV  vHJ6w9EVZD8
# 1418                             8eight  "Let me go" MV  zaSyqefQm8s
#
# [1419 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_hybe.csv", index=False)

# %% [markdown]
# ### (2번) NewJeans
# 뉴진스

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][1], #NewJeans 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
# [1641 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_newjeans.csv", index=False)

# %% [markdown]
# ### (3번) BANGTANTV
# 방탄소년단 BTS

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][2], #BANGTANTV 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
# [1641 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_bts.csv", index=False)

# %% [markdown]
# ### (4번) LE SSERAFIM
# 르세라핌

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][3], #LE SSERAFIM 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
# [1641 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_lesserafim.csv", index=False)

# %% [markdown]
# ### (5번) SEVENTEEN
# 세븐틴

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][4], #SEVENTEEN 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
# [1641 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_seventeen.csv", index=False)

# %% [markdown]
# ### (6번) TOMORROW X TOGETHER OFFICIAL
# 투모로우바이투게더

# %%
video_title = [] #동영상 제목
video_id = [] #동영상 id

playlistItems_request = youtube.playlistItems().list(
    playlistId = channel["playlist_id"][5], #TOMORROW X TOGETHER OFFICIAL 채널의 playlist id
    part = "snippet",
    maxResults = 50
)
    
while playlistItems_request:
    playlistItems_response = playlistItems_request.execute()
        
    for item in playlistItems_response["items"]:
        video_id.append(item["snippet"]["resourceId"]["videoId"])
        video_title.append(item["snippet"]["title"])
            
    playlistItems_request = youtube.playlistItems().list_next( #다음 페이지의 결과값들을 불러옴
        playlistItems_request, playlistItems_response
    )

item_df = pd.DataFrame({"video_title": video_title, "video_id": video_id})
item_df
# Out:
#                                             video_title     video_id
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
# [1641 rows x 2 columns]

# %%
#item_df를 csv파일로 저장
item_df.to_csv("../../../data/YouTube/item_txt.csv", index=False)

# %% [markdown]
# # (4) 동영상 데이터 추출
# Videos: list 리소스를 사용함.

# %% [markdown]
# <span style = "color:Red;">**!!!주의 사항!!!**</span>
#
# 이 단계에서는 요청량이 많아서 API 요청이 끊길 수 있음!!
# <br>적당히 데이터량 조절하면서 보는게 좋을 수도!!
# <br>여기선 무조건 저장 필수!!!!!!!!

# %%
item_hybe = pd.read_csv("../../../data/YouTube/item_hybe.csv")
item_hybe
# Out:
#                                             video_title     video_id
# 0                          V 'Slow Dancing' Official MV  eI0iTRS0Ha8
# 1                      V 'Slow Dancing' Official Teaser  mJ1NFKfTF9M
# 2     [HYBE x Geffen] Dream Academy - Mission 1 "Dan...  KVzm2wmG6lU
# 3     [HYBE x Geffen] Dream Academy - Mission 1 "Sti...  1pO6_BCH1kM
# 4     [HYBE x Geffen] Dream Academy - Mission 1 "Pin...  JrK_KV0_zwg
# ...                                                 ...          ...
# 1414                         에이트(8eight) 윤도현의 러브레터 연습현장  WQiNfk8qk_o
# 1415              8eight "I love you (feat.Jessica)" MV  _i99DG6AiLQ
# 1416                                  Bananagirl "S" MV  GJRYr-SMaCo
# 1417                   8eight "Forget Love and Sing" MV  vHJ6w9EVZD8
# 1418                             8eight  "Let me go" MV  zaSyqefQm8s
#
# [1419 rows x 2 columns]

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_hybe)): #HYBE LABELS
    request = youtube.videos().list(
        id = item_hybe["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df
# Out:
#                                                   title      videoId  \
# 0                          V 'Slow Dancing' Official MV  eI0iTRS0Ha8
# 1                      V 'Slow Dancing' Official Teaser  mJ1NFKfTF9M
# 2     [HYBE x Geffen] Dream Academy - Mission 1 "Dan...  KVzm2wmG6lU
# 3     [HYBE x Geffen] Dream Academy - Mission 1 "Sti...  1pO6_BCH1kM
# 4     [HYBE x Geffen] Dream Academy - Mission 1 "Pin...  JrK_KV0_zwg
# ...                                                 ...          ...
# 1414                         에이트(8eight) 윤도현의 러브레터 연습현장  WQiNfk8qk_o
# 1415              8eight "I love you (feat.Jessica)" MV  _i99DG6AiLQ
# 1416                                  Bananagirl "S" MV  GJRYr-SMaCo
# 1417                   8eight "Forget Love and Sing" MV  vHJ6w9EVZD8
# 1418                             8eight  "Let me go" MV  zaSyqefQm8s
#
#             date categoryId      view     like dislike comment  \
# 0     2023-09-08         10  10429136  1833090       -  170975
# 1     2023-09-07         10   1981919   489964       -   20651
# 2     2023-09-06         10    446467    35632       -    2222
# 3     2023-09-06         10    646113    74834       -    6290
# 4     2023-09-06         10    736061    57032       -    2618
# ...          ...        ...       ...      ...     ...     ...
# 1414  2008-06-27         24     46640     2000       -     197
# 1415  2008-06-18         10    320031     4072       -     688
# 1416  2008-06-10         10    221284     5460       -    1112
# 1417  2008-06-10         10    218413     5458       -    1077
# 1418  2008-06-10         10    923523    33423       -   12795
#
#                                             tags hour min sec
# 0                   HYBE|HYBE LABELS|하이브|하이브레이블즈    -   3  11
# 1                   HYBE|HYBE LABELS|하이브|하이브레이블즈    -   -  29
# 2                   HYBE|HYBE LABELS|하이브|하이브레이블즈    -   3   4
# 3                   HYBE|HYBE LABELS|하이브|하이브레이블즈    -   2  54
# 4                   HYBE|HYBE LABELS|하이브|하이브레이블즈    -   2  28
# ...                                          ...  ...  ..  ..
# 1414              에이트|주희|레이싱걸|비키니|eight|윤도현|러브레터    -   2  35
# 1415  에이트 주희 음악 제시카 뮤직 비디오 뮤비 mv|I love you 소녀시대    -   3  41
# 1416         바나나|바나나걸|이현지|초콜릿|초콜렛|에스|뮤직비디오|MV|뮤비    -   3  35
# 1417        에이트|주희|음악|뮤직|비디오|뮤비|mv|사랑을|잃고|난|노래하네    -   4   5
# 1418        에이트|주희|음악|뮤직|비디오|뮤비|let|me|go|8eight    -   3  48
#
# [1419 rows x 12 columns]

# %% [markdown]
# ▲ 각 영상들의 업로드 날짜를 보면 최신순으로 정렬됨을 알 수 있음.
# <br>=> 유튜브로 직접 들어가서 HYBE LABELS의 채널 '동영상' 카테고리를 누르면 위와 동일한 순서대로 정렬됨을 알 수 있음.

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_hybe.csv", index=False)

# %% [markdown]
# ### (2번) NewJeans
# 뉴진스

# %%
item_newjeans = pd.read_csv("../../../data/YouTube/item_newjeans.csv")
item_newjeans
# Out:
#                                             video_title     video_id
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
# [1641 rows x 2 columns]

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_newjeans)): #NewJeans
    request = youtube.videos().list(
        id = item_newjeans["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df
# Out:
#                                                   title      videoId  \
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
#             date categoryId     view    like dislike comment  \
# 0     2023-09-09         10   193427   43681       -     450
# 1     2023-09-08         10   298898   51780       -     471
# 2     2023-09-07         10    71532   12226       -     123
# 3     2023-09-06         10  1316626  103462       -    2325
# 4     2023-09-05         10   495698   52949       -    1558
# ...          ...        ...      ...     ...     ...     ...
# 1636  2012-12-27         24    99050    4655       -     299
# 1637  2012-12-27         24   375640   14582       -    1162
# 1638  2012-12-24         24   149683    9813       -     270
# 1639  2012-12-24         24   197185   11480       -     293
# 1640  2012-12-24         24   273026   14078       -     594
#
#                                                    tags hour min sec
# 0                                                     -    -   -  31
# 1                                                     -    -   -  22
# 2     에스쿱스|정한|조슈아|호시|원우|우지|디에잇|민규|도겸|승관|버논|디노|SCOUPS...    -   -  59
# 3     에스쿱스|정한|조슈아|호시|원우|우지|디에잇|민규|도겸|승관|버논|디노|SCOUPS...    -  26   9
# 4     에스쿱스|정한|조슈아|호시|원우|우지|디에잇|민규|도겸|승관|버논|디노|SCOUPS...    -  11  36
# ...                                                 ...  ...  ..  ..
# 1636    Special|17TV|Christmas|Event|'Seventeen|TV'|002    -  27  22
# 1637    Special|17TV|Christmas|Event|'Seventeen|TV'|001    -  28  16
# 1638                                     121215|17|ver3    -   1   3
# 1639                                     121215|17|ver2    -   1   4
# 1640                                     121128|17|ver1    -   -  24
#
# [1641 rows x 12 columns]

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_newjeans.csv", index=False)

# %% [markdown]
# ### (3번) BANGTANTV
# 방탄소년단

# %%
item_bts = pd.read_csv("../../../data/YouTube/item_bts.csv")
item_bts
# Out:
#                                             video_title     video_id
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
# [1641 rows x 2 columns]

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_bts)): #BANGTANTV
    request = youtube.videos().list(
        id = item_bts["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df
# Out:
#                                                   title      videoId  \
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
#             date categoryId     view    like dislike comment  \
# 0     2023-09-09         10   193427   43754       -     451
# 1     2023-09-08         10   299432   51813       -     472
# 2     2023-09-07         10    71585   12223       -     123
# 3     2023-09-06         10  1316626  103475       -    2325
# 4     2023-09-05         10   495803   52952       -    1558
# ...          ...        ...      ...     ...     ...     ...
# 1636  2012-12-27         24    99050    4655       -     299
# 1637  2012-12-27         24   375640   14582       -    1162
# 1638  2012-12-24         24   149684    9813       -     270
# 1639  2012-12-24         24   197185   11480       -     293
# 1640  2012-12-24         24   273026   14078       -     594
#
#                                                    tags hour min sec
# 0                                                     -    -   -  31
# 1                                                     -    -   -  22
# 2     에스쿱스|정한|조슈아|호시|원우|우지|디에잇|민규|도겸|승관|버논|디노|SCOUPS...    -   -  59
# 3     에스쿱스|정한|조슈아|호시|원우|우지|디에잇|민규|도겸|승관|버논|디노|SCOUPS...    -  26   9
# 4     에스쿱스|정한|조슈아|호시|원우|우지|디에잇|민규|도겸|승관|버논|디노|SCOUPS...    -  11  36
# ...                                                 ...  ...  ..  ..
# 1636    Special|17TV|Christmas|Event|'Seventeen|TV'|002    -  27  22
# 1637    Special|17TV|Christmas|Event|'Seventeen|TV'|001    -  28  16
# 1638                                     121215|17|ver3    -   1   3
# 1639                                     121215|17|ver2    -   1   4
# 1640                                     121128|17|ver1    -   -  24
#
# [1641 rows x 12 columns]

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_bts.csv", index=False)

# %% [markdown]
# ### (4번) LE SSERAFIM
# 르세라핌

# %%
item_lesserafim = pd.read_csv("../../../data/YouTube/item_lesserafim.csv")
item_lesserafim
# Out:
#                                             video_title     video_id
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
# [1641 rows x 2 columns]

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_lesserafim)): #LE SSERAFIM
    request = youtube.videos().list(
        id = item_lesserafim["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df
# Out:
#                                                   title      videoId  \
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
#             date categoryId     view    like dislike comment  \
# 0     2023-09-09         10   194613   43836       -     451
# 1     2023-09-08         10   299432   51841       -     472
# 2     2023-09-07         10    71585   12227       -     123
# 3     2023-09-06         10  1317285  103489       -    2325
# 4     2023-09-05         10   495803   52955       -    1558
# ...          ...        ...      ...     ...     ...     ...
# 1636  2012-12-27         24    99050    4655       -     299
# 1637  2012-12-27         24   375642   14582       -    1162
# 1638  2012-12-24         24   149684    9813       -     270
# 1639  2012-12-24         24   197186   11480       -     293
# 1640  2012-12-24         24   273026   14078       -     594
#
#                                                    tags hour min sec
# 0                                                     -    -   -  31
# 1                                                     -    -   -  22
# 2     에스쿱스|정한|조슈아|호시|원우|우지|디에잇|민규|도겸|승관|버논|디노|SCOUPS...    -   -  59
# 3     에스쿱스|정한|조슈아|호시|원우|우지|디에잇|민규|도겸|승관|버논|디노|SCOUPS...    -  26   9
# 4     에스쿱스|정한|조슈아|호시|원우|우지|디에잇|민규|도겸|승관|버논|디노|SCOUPS...    -  11  36
# ...                                                 ...  ...  ..  ..
# 1636    Special|17TV|Christmas|Event|'Seventeen|TV'|002    -  27  22
# 1637    Special|17TV|Christmas|Event|'Seventeen|TV'|001    -  28  16
# 1638                                     121215|17|ver3    -   1   3
# 1639                                     121215|17|ver2    -   1   4
# 1640                                     121128|17|ver1    -   -  24
#
# [1641 rows x 12 columns]

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_lesserafim.csv", index=False)

# %% [markdown]
# ### (5번) SEVENTEEN
# 세븐틴

# %%
item_seventeen = pd.read_csv("../../../data/YouTube/item_seventeen.csv")
item_seventeen
# Out:
#                                             video_title     video_id
# 0     Can't help but dance with @NewKidsontheBlock 🕺...  d1I5IKI1pFM
# 1     #PSYCHO웃음챌린지 😈 with #LINYI #JUN #SEVENTEEN #PS...  Kr8Rbx3tb9g
# 2                      #꼬잉_픽📌 지금부터 여러분도 웃음을 참게 됩니다 레드썬🤫  vJez_825yVY
# 3     [GOING SEVENTEEN] EP.92 전참시 벌 #2 (Point of Omn...  rnFPIn1aEO0
# 4     [SVT Record] 하니의 베를린 패션위크 Vlog | 심장 쫄깃해지는(?) 베...  IycDTCrBvn8
# ...                                                 ...          ...
# 1636  [Special 17TV] Christmas Event 'Seventeen TV' ...  erkiH5eGcvQ
# 1637  [Special 17TV] Christmas Event 'Seventeen TV' ...  55lRsp-8bR8
# 1638                   [Teaser] ''Seventeen TV'' - ver3  NrikKYe8cn0
# 1639                   [Teaser] ''Seventeen TV'' - ver2  svAPrhyEw0w
# 1640                   [Teaser] ''Seventeen TV'' - ver1  u5DHkfIrZ7k
#
# [1641 rows x 2 columns]

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_seventeen)): #SEVENTEEN
    request = youtube.videos().list(
        id = item_seventeen["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Input In [149], in <cell line: 26>()
#      26 for i in range(len(item_seventeen)): #SEVENTEEN
#      27     request = youtube.videos().list(
#      28         id = item_seventeen["video_id"][i],
#      29         part = "snippet,contentDetails,statistics"
#      30     )
# ---> 31     video_response = request.execute()
#      33     if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
#      34         titles.append("-")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?id=rVGdsu7kT7I&part=snippet%2CcontentDetails%2Cstatistics&key=AIzaSyCR_i3URXYE3p_g_KW5K0PFzXvIXpiAbYk&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_seventeen.csv", index=False)

# %% [markdown]
# ### (6번) TOMORROW X TOGETHER OFFICIAL
# 투모로우바이투게더

# %%
item_txt = pd.read_csv("../../../data/YouTube/item_txt.csv")
item_txt

# %%
titles = [] #동영상 제목
ids = [] #동영상 id
dates = [] #동영상 업로드 날짜
category_ids = [] #동영상 카테고리 id
views = [] #조회수
likes = [] #좋아요 수
dislikes = [] #싫어요 수
comments = [] #댓글 수
tags = [] #태그 정보

hours = [] #동영상 재생길이(시)
mins = [] #동영상 재생길이(분)
secs = [] #동영상 재생길이(초)

#리스트 형태의 tags 정보를 일련의 문자열로 변환해주는 함수
def Tags2Strings(tags_list):
    
    string = ""
    for i in range(len(tags_list)):
        string = string + tags_list[i] + "|"
    string = string[:-1] #문자열 맨 끝에 붙은 "|"은 없애버림
    
    return string

#데이터 추출
for i in range(len(item_txt)): #TOMORROW X TOGETHER OFFICIAL
    request = youtube.videos().list(
        id = item_txt["video_id"][i],
        part = "snippet,contentDetails,statistics"
    )
    video_response = request.execute()
    
    if video_response["items"] == []: #동영상 정보가 없을 경우 '-'값 입력
        titles.append("-")
        ids.append("-")
        dates.append("-")
        category_ids.append("-")
        views.append("-")
        likes.append("-")
        dislikes.append("-")
        comments.append("-")
        tags.append("-")
        hours.append("-")
        mins.append("-")
        secs.append("-")
    
    else:
        titles.append(video_response["items"][0]["snippet"]["title"])
        ids.append(video_response["items"][0]["id"])
        dates.append(video_response["items"][0]["snippet"]["publishedAt"].split("T")[0])
        category_ids.append(video_response["items"][0]["snippet"]["categoryId"])
        
        #views 데이터
        if "viewCount" in video_response["items"][0]["statistics"].keys():
            views.append(video_response["items"][0]["statistics"]["viewCount"])
            
        else:
            views.append("-")
        
        #comments 데이터
        if "commentCount" in video_response["items"][0]["statistics"].keys():
            comments.append(video_response["items"][0]["statistics"]["commentCount"])
            
        else:
            comments.append("-")
        
        #likes 데이터
        if "likeCount" in video_response["items"][0]["statistics"].keys():
            likes.append(video_response["items"][0]["statistics"]["likeCount"])
            
        else: #likeCount가 없는 경우도 있음
            likes.append("-")
        
        #dislikes 데이터
        if "dislikeCount" in video_response["items"][0]["statistics"].keys():
            dislikes.append(video_response["items"][0]["statistics"]["dislikeCount"])
            
        else:
            dislikes.append("-")
        
        #tags 데이터
        if "tags" in video_response["items"][0]["snippet"].keys():
            tags_string = video_response["items"][0]["snippet"]["tags"]
            tags.append(Tags2Strings(tags_string))
            
        else: #tags가 없는 경우도 있음(shorts 형식의 영상들)
            tags.append("-")
        
        #hour, min, sec 데이터
        duration = re.findall(r'\d+', video_response["items"][0]["contentDetails"]["duration"])
        if len(duration) == 3:
            hours.append(duration[0])
            mins.append(duration[1])
            secs.append(duration[2])
        elif len(duration) == 2:
            hours.append("-")
            mins.append(duration[0])
            secs.append(duration[1])
        else:
            hours.append("-")
            mins.append("-")
            secs.append(duration[0])
        
        
video_df = pd.DataFrame({"title": titles, "videoId": ids, "date": dates, "categoryId": category_ids,
                        "view": views, "like": likes, "dislike": dislikes, "comment": comments, "tags": tags,
                        "hour": hours, "min": mins, "sec": secs})
video_df

# %%
#video_df를 csv파일로 저장
video_df.to_csv("../../../data/YouTube/video_txt.csv", index=False)
